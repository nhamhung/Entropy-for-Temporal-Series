# %% [markdown]
# # Correlation between entropy/FD metrics
#
# Requires the [seaborn](https://seaborn.pydata.org/) and [pingouin](https://pingouin-stats.org) packages.

# %%
from entropy import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(context='talk')

df = pd.DataFrame()

# Generate 1000 1Hz sines with increasing noise
np.random.seed(123)
N = 1000
sf = 100
n_sines = 100
noises_factor = np.linspace(0, 1, n_sines)
noises = np.random.rand(n_sines, N)
sines = np.zeros(shape=(n_sines, N))
for i in range(n_sines):
    sines[i] = np.sin(2 * np.pi * np.arange(N) / sf) + noises_factor[i] * noises[i, :]
    
# Plot the first and last sines
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 6), sharex=True, sharey=False)
ax1.plot(sines[0])
ax2.plot(sines[-1])

# %%
# Compute the entropy metrics
for i in range(n_sines):
    df = df.append({'PermEnt': perm_entropy(sines[i], order=3, normalize=True),
                    'SVDEnt' : svd_entropy(sines[i], order=3, normalize=True),
                    'SpecEnt' : spectral_entropy(sines[i], sf, method='welch', normalize=True),
                    'AppEnt': app_entropy(sines[i], order=2),
                    'SampleEnt': sample_entropy(sines[i], order=2),
                    'PetrosianFD': petrosian_fd(sines[i]),
                    'KatzFD': katz_fd(sines[i]),
                    'HiguchiFD': higuchi_fd(sines[i]),
                    # 'DFA': detrended_fluctuation(sines[i])
                   }, ignore_index=True)

df.head()
# Out:
#      AppEnt  HiguchiFD    KatzFD   PermEnt  PetrosianFD    SVDEnt  SampleEnt  \
# 0  0.200446   1.013872  2.145324  0.447237     1.001155  0.177294   0.163998
# 1  0.201692   1.014700  2.141333  0.482647     1.001959  0.192173   0.164066
# 2  0.203296   1.016756  2.144228  0.536770     1.003445  0.204147   0.165301
# 3  0.211349   1.019776  2.137527  0.610048     1.005823  0.213686   0.169001
# 4  0.224400   1.026540  2.147726  0.625656     1.006385  0.224054   0.175866
#
#     SpecEnt
# 0  0.184779
# 1  0.184847
# 2  0.184923
# 3  0.185038
# 4  0.185502

# %% [markdown]
# ## Pairwise correlations

# %%
sns.pairplot(df, markers='+')

# %%
from pingouin import pairwise_corr
pairwise_corr(df).sort_values(by=['r2'], ascending=False)
# Out:
#               X            Y   method       tail    n         r         CI95%  \
# 5        AppEnt    SampleEnt  pearson  two-sided  100  0.998837    [1.0, 1.0]
# 10    HiguchiFD       SVDEnt  pearson  two-sided  100  0.998227    [1.0, 1.0]
# 4        AppEnt       SVDEnt  pearson  two-sided  100  0.991435  [0.99, 0.99]
# 25       SVDEnt    SampleEnt  pearson  two-sided  100  0.985636  [0.98, 0.99]
# 11    HiguchiFD    SampleEnt  pearson  two-sided  100  0.985633  [0.98, 0.99]
# 16       KatzFD    SampleEnt  pearson  two-sided  100  0.983181  [0.98, 0.99]
# 1        AppEnt       KatzFD  pearson  two-sided  100  0.981546  [0.97, 0.99]
# 15       KatzFD       SVDEnt  pearson  two-sided  100  0.973280  [0.96, 0.98]
# 7     HiguchiFD       KatzFD  pearson  two-sided  100  0.971375  [0.96, 0.98]
# 27    SampleEnt      SpecEnt  pearson  two-sided  100  0.966855  [0.95, 0.98]
# 17       KatzFD      SpecEnt  pearson  two-sided  100  0.960517  [0.94, 0.97]
# 18      PermEnt  PetrosianFD  pearson  two-sided  100  0.956273  [0.94, 0.97]
# 6        AppEnt      SpecEnt  pearson  two-sided  100  0.955994  [0.94, 0.97]
# 26       SVDEnt      SpecEnt  pearson  two-sided  100  0.924965  [0.89, 0.95]
# 12    HiguchiFD      SpecEnt  pearson  two-sided  100  0.917994  [0.88, 0.94]
# 22  PetrosianFD       SVDEnt  pearson  two-sided  100  0.827031  [0.75, 0.88]
# 9     HiguchiFD  PetrosianFD  pearson  two-sided  100  0.815969  [0.74, 0.87]
# 3        AppEnt  PetrosianFD  pearson  two-sided  100  0.748629  [0.65, 0.82]
# 14       KatzFD  PetrosianFD  pearson  two-sided  100  0.732441  [0.63, 0.81]
# 23  PetrosianFD    SampleEnt  pearson  two-sided  100  0.724155  [0.62, 0.81]
# 19      PermEnt       SVDEnt  pearson  two-sided  100  0.679104  [0.56, 0.77]
# 8     HiguchiFD      PermEnt  pearson  two-sided  100  0.656005  [0.53, 0.76]
# 24  PetrosianFD      SpecEnt  pearson  two-sided  100  0.602147  [0.46, 0.71]
# 2        AppEnt      PermEnt  pearson  two-sided  100  0.583107   [0.44, 0.7]
# 13       KatzFD      PermEnt  pearson  two-sided  100  0.570722  [0.42, 0.69]
# 20      PermEnt    SampleEnt  pearson  two-sided  100  0.556706   [0.4, 0.68]
# 21      PermEnt      SpecEnt  pearson  two-sided  100  0.444579  [0.27, 0.59]
# 0        AppEnt    HiguchiFD  pearson  two-sided  100       NaN           NaN
#
#           r2    adj_r2         z          p-unc        BF10     power
# 5   0.997676  0.997628  3.724778  7.114733e-131  3.441e+125  1.000000
# 10  0.996457  0.996384  3.513639  6.693537e-122  5.579e+116  1.000000
# 4   0.982944  0.982592  2.724480   1.866141e-88   9.691e+83  1.000000
# 25  0.971478  0.970890  2.464477   1.641616e-77   1.852e+73  1.000000
# 11  0.971472  0.970884  2.464373   1.658137e-77   1.834e+73  1.000000
# 16  0.966644  0.965957  2.384966   3.529814e-74   1.009e+70  1.000000
# 1   0.963432  0.962678  2.338173   3.198286e-72   1.223e+68  1.000000
# 15  0.947274  0.946187  2.151022   1.976443e-64   2.875e+60  1.000000
# 7   0.943569  0.942406  2.116104   5.517650e-63   1.104e+59  1.000000
# 27  0.934809  0.933464  2.041649   6.529911e-60   1.082e+56  1.000000
# 17  0.922593  0.920997  1.952548   2.968663e-56   2.844e+52  1.000000
# 18  0.914459  0.912695  1.900419   3.989041e-54   2.348e+50  1.000000
# 6   0.913924  0.912149  1.897158   5.415943e-54   1.741e+50  1.000000
# 26  0.855560  0.852581  1.622352   5.795841e-43   2.811e+39  1.000000
# 12  0.842712  0.839469  1.576118   3.798736e-41   4.702e+37  1.000000
# 22  0.683981  0.677465  1.178669   2.962504e-26   1.331e+23  1.000000
# 9   0.665805  0.658914  1.144634   4.649378e-25    9.08e+21  1.000000
# 3   0.560446  0.551383  0.969829   3.429379e-19   1.751e+16  1.000000
# 14  0.536470  0.526912  0.933973   4.727084e-18   1.367e+15  1.000000
# 23  0.524400  0.514594  0.916326   1.684111e-17   3.978e+14  1.000000
# 19  0.461182  0.450073  0.827449   8.109499e-15   9.926e+11  1.000000
# 8   0.430343  0.418597  0.785768   1.281773e-13   6.853e+10  1.000000
# 24  0.362581  0.349438  0.696509   3.427742e-11   3.102e+08  1.000000
# 2   0.340014  0.326406  0.667158   1.943591e-10   5.833e+07  0.999998
# 13  0.325723  0.311820  0.648592   5.666263e-10   2.085e+07  0.999996
# 20  0.309922  0.295693  0.628047   1.804772e-09   6.853e+06  0.999989
# 21  0.197651  0.181108  0.477924   3.588625e-06    4912.994  0.997178
# 0        NaN       NaN       NaN            NaN         nan       NaN

# %% [markdown]
# ## Clustermap

# %%
sns.clustermap(df, row_cluster=False, standard_scale=1)
